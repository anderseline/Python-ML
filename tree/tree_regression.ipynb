# %% [markdown]
# # Regression

# %%
from sklearn import tree

# %%
X = [[0,0],[3,3]]
y = [0.75, 3]

# %%
tree_reg = tree.DecisionTreeRegressor(random_state=0)

# %%
tree_reg = tree_reg.fit(X, y)

# %%
import numpy as np 
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt 

rng = np.random.RandomState(1)
X = np.sort(5 * rng.rand(80, 1), axis=0)
y = np.sin(X).ravel()
y[::5] += 3 * (0.5 - rng.rand(16))

regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_1.fit(X,y)
regr_2.fit(X,y)

X_test = np.arange(0,5,0.01)[:, np.newaxis]
y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)

plt.figure(figsize=(10,8))
plt.scatter(X,y,s=20, edgecolor='black', 
            c='darkorange', label='data')
plt.plot(X_test, y_1, color='yellowgreen', label='max depth 2', linewidth=2)
plt.plot(X_test, y_2, color='cornflowerblue', label='max depth 5', linewidth=2)
plt.legend()

# %% [markdown]
# Depth of 5 is overfitted. Can add a ```min_samples_leaf``` parameter to reduce overfitting. Sample size must be greater than 10

# %%
rng = np.random.RandomState(1)
X = np.sort(5 * rng.rand(80, 1), axis=0)
y = np.sin(X).ravel()
y[::5] += 3 * (0.5 - rng.rand(16))

regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5, min_samples_leaf=10)
regr_1.fit(X,y)
regr_2.fit(X,y)

X_test = np.arange(0,5,0.01)[:, np.newaxis]
y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)

plt.figure(figsize=(10,8))
plt.scatter(X,y,s=20, edgecolor='black', 
            c='darkorange', label='data')
plt.plot(X_test, y_1, color='yellowgreen', label='max depth 2', linewidth=2)
plt.plot(X_test, y_2, color='cornflowerblue', label='max depth 5', linewidth=2)
plt.legend()
